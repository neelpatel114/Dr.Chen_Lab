# %%
import pandas as pd 
import numpy as np 
import os 

sczPath = "/mnt/data_schen_1/jingchun/scz_plink_scores/"
bpPath = "/mnt/data_schen_1/jingchun/Affy6_BP_Scores/"
mdgainPath = "/mnt/data_schen_1/jingchun/MD_GAIN_Scores/"
mdPath = "/mnt/data_schen_1/jingchun/Dutch_twin_MD_Scores/"
WTCCCPath = "/mnt/data_schen_1/jingchun/WTCCC_Scores/"
adPath = "/mnt/data_schen_1/jingchun/AD_Scores/"

baseFile = pd.read_csv("/Users/npatel/Desktop/Dr.Chen_Lab/repo/Dr.Chen_Lab/Neel/Python_Notebooks/scores_task_files.txt", sep = '\t' )

# %%
baseFile
# Out:
#                                                 bases    OR  \
# 0   AD_sumstats_Jansenetal_2019sept_1.addsnpid.txt.gz  BETA
# 1   ADHD_DBDs_GWAS_meta_January2021_1.addsnpid.txt.gz    OR
# 2                      anorexia_2.out.addsnpid.txt.gz    OR
# 3              anxiety.meta.full.cc_2.addsnpid.txt.gz  BETA
# 4                BDSCZvsCONT.sumstats.addsnpid.txt.gz    OR
# 5                   BDvsCONT.sumstats.addsnpid.txt.gz    OR
# 6           BMI.ACTIVE.ALL.European_2.addsnpid.txt.gz  BETA
# 7            cad.add.160614.website_1.addsnpid.txt.gz  BETA
# 8             cannabis_meta_results_2.addsnpid.txt.gz  BETA
# 9   CUD_EUR_casecontrol_public_11.14.2020_1.addsnp...  BETA
# 10  daner_adhd_meta_filtered_NA_iPSYCH23_PGC11_sig...    OR
# 11  Davies2016_UKB_college_summary_results_2207201...  BETA
# 12  Davies2016_UKB_Memory_summary_results_22072016...  BETA
# 13  Davies2016_UKB_Reaction_time_summary_results_2...  BETA
# 14  Davies2016_UKB_VNR_summary_results_22072016_1....  BETA
# ...

# %%
for filename
